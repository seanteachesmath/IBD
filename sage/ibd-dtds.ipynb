# %%
f(x) = 0.89*x
a = plot(f,x,0,5, ymin = 0, ymax = 5, color="black", linestyle="solid", gridlines = "minor") + plot(x, x, 0, 5, color="black", linestyle="dotted", axes_labels=["$x_{t}$", "$x_{t+1}$"], aspect_ratio=1)
a
save(a, "DTDS.png")

x0 = 0.8
p = plot(f,x,0,1, ymin = 0, ymax = 1, color="black", linestyle="solid", gridlines = "minor") + plot(x, x, 0, 1, color="black", linestyle="dotted", axes_labels=["$x_{t}$", "$x_{t+1}$"], aspect_ratio=1)
x1 = f(x0)
q = points(((0,x0), (1, x1)), ymax = 1, gridlines = "minor", axes_labels=["$xt$", "$x_{t}$"])# + line([(0,x0), (1, x1)])
p = p + line([(x0, 0), (x0, x1)]) + line([(x0, x1), (x1, x1)])
x0 = x1

for i in srange(100):
    x1 = f(x0)
    p = p + line([(x0, x0), (x0, x1)]) + line([(x0, x1), (x1, x1)])
    q = q + points(((i+1,x0), (i+2, x1)))# + line([(i+1,x0), (i+2, x1)])
    x0 = x1
show(p)
filename = "cobwebbed-decay.png"
save(p, filename)
q = q + plot(0.8*exp(log(0.89)*x), xmin = 0, xmax = 100, color = "red")
show(q)
filename = "solution-decay.png"
save(q, filename, aspect_ratio = 100)
# Out:
# Graphics object consisting of 204 graphics primitives
# Graphics object consisting of 102 graphics primitives

# %%
a = plot(0.5*x*(1-x),x,0,1, ymin = 0, ymax = 1, color="black", linestyle="solid", gridlines = "minor") + plot(x, x, 0, 1, color="black", linestyle="dotted", axes_labels=["$x_{t}$", "$x_{t+1}$"], aspect_ratio=1)
a
#save(a, "log1.png")
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
a = plot(1.5*x*(1-x),x,0,1, ymin = 0, ymax = 1, color="black", linestyle="solid", gridlines = "minor") + plot(x, x, 0, 1, color="black", linestyle="dotted", axes_labels=["$x_{t}$", "$x_{t+1}$"], aspect_ratio=1)
a
save(a, "log2.png")

# %%
a = plot(2.1*x*(1-x),x,0,1, ymin = 0, ymax = 1, color="black", linestyle="solid", gridlines = "minor") + plot(x, x, 0, 1, color="black", linestyle="dotted", axes_labels=["$x_{t}$", "$x_{t+1}$"], aspect_ratio=1)
a
save(a, "log3.png")

# %%
a = plot(2.5*x*(1-x),x,0,1, ymin = 0, ymax = 1, color="black", linestyle="solid", gridlines = "minor") + plot(x, x, 0, 1, color="black", linestyle="dotted", axes_labels=["$x_{t}$", "$x_{t+1}$"], aspect_ratio=1)
a
save(a, "log4.png")

# %%
a = plot(3.1*x*(1-x),x,0,1, ymin = 0, ymax = 1, color="black", linestyle="solid", gridlines = "minor") + plot(x, x, 0, 1, color="black", linestyle="dotted", axes_labels=["$x_{t}$", "$x_{t+1}$"], aspect_ratio=1)
a
save(a, "log5.png")

# %%
for r in [0.5, 1.5, 2.1, 2.5, 3.1, 3.9]:
    a = plot(r*x*(1-x),x,0,1, ymin = 0, ymax = 1, color="black", linestyle="solid", gridlines = "minor") + plot(x, x, 0, 1, color="black", linestyle="dotted", axes_labels=["$x_{t}$", "$x_{t+1}$"], aspect_ratio=1)
    a
    filename = os.path.join(str(round(r,2)),"_png").replace("/","").replace(".","").replace("_",".")
    save(a, filename)

# %%
for r in [0.5, 1.5, 2.1, 2.5, 3.1, 3.9]:
    f(x) = r*x*(1-x)
    x0 = 0.6
    y0 = 0.9
    p = plot(f,x,0,1, ymin = 0, ymax = 1, color="black", linestyle="solid", gridlines = "minor") + plot(x, x, 0, 1, color="black", linestyle="dotted", axes_labels=["$x_{t}$", "$x_{t+1}$"], aspect_ratio=1)
    x1 = f(x0)
    y1 = f(y0)
    p = p + line([(x0, 0), (x0, x1)]) + line([(x0, x1), (x1, x1)]) + line([(y0, 0), (y0, y1)], color = "red") + line([(y0, y1), (y1, y1)], color = "red")
    x0 = x1
    y0 = y1
    for i in srange(100):
        x1 = f(x0)
        y1 = f(y0)
        p = p + line([(x0, x0), (x0, x1)]) + line([(x0, x1), (x1, x1)]) + line([(y0, y0), (y0, y1)], color = "red") + line([(y0, y1), (y1, y1)], color = "red")
        x0 = x1
        y0 = y1
    show(p)
    filename = os.path.join(str(round(r,2)),"-cobweb_png").replace("/","").replace(".","").replace("_",".")
    save(p, filename)
# Out:
# Graphics object consisting of 406 graphics primitives
# Graphics object consisting of 406 graphics primitives
# Graphics object consisting of 406 graphics primitives
# Graphics object consisting of 406 graphics primitives
# Graphics object consisting of 406 graphics primitives
# Graphics object consisting of 406 graphics primitives

# %%
for r in [0.5, 1.5, 2.1, 2.5, 3.1, 3.9]:
    f(x) = r*x*(1-x)
    x0 = 0.6
    y0 = 0.9
    p = plot(0,x,0,100, ymin = 0, ymax = 1, color="black", linestyle="solid", gridlines = "minor", axes_labels=["$t$", "$x_{t}$"])
    x1 = f(x0)
    y1 = f(y0)
    p = p + line([(0, x0), (1, x1)]) + points(((0, x0), (1, x1))) + points(((0, y0), (1, y1)), color = "red") + line([(0, y0), (1, y1)], color = "red")
    x0 = x1
    y0 = y1
    for i in srange(100):
        x1 = f(x0)
        y1 = f(y0)
        p = p + line([(i+1, x0), (i+2, x1)]) + points(((i + 2, x1))) + points((i+2, y1), color = "red")+ line([(i+1, y0), (i+2, y1)], color = "red")

        x0 = x1
        y0 = y1

    show(p)
    filename = os.path.join(str(round(r,2)),"-sol_png").replace("/","").replace(".","").replace("_",".")
    if (r < 3):
        save(p, filename, xmin=0, xmax=20, aspect_ratio = 20)
    else:
        save(p, filename, aspect_ratio = 100)
# Out:
# Graphics object consisting of 405 graphics primitives
# Graphics object consisting of 405 graphics primitives
# Graphics object consisting of 405 graphics primitives
# Graphics object consisting of 405 graphics primitives
# Graphics object consisting of 405 graphics primitives
# Graphics object consisting of 405 graphics primitives

# %%
var('r')
solve(x==r*r*x*(1-x)*(1-r*x*(1-x)),x)
# Out:
# [x == 1/2*(r - sqrt(r^2 - 2*r - 3) + 1)/r, x == 1/2*(r + sqrt(r^2 - 2*r - 3) + 1)/r, x == (r - 1)/r, x == 0]
